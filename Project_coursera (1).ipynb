# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Lalit kumar</b>
# Desired to be an engineer

# %% [markdown]
# <i>I am interested in data science because it is more analyzing , predicting and solving rather than just coding</i>

# %% [markdown]
# ### Code to find factorial of a number using recursion in python

# %%
def fact(n):
    if n==1 or n==0:
        return 1
    else:
        return n*fact(n-1)
print("The factorial of 5 is ", fact(5))
# Out:
# The factorial of 5 is  120

# %% [markdown]
# <a href='www.ibm.com'>IBM</a>
# <ul>
#     <li>one</li>
#     <li>two</li>
# </ul>
# <ol>
#     <li>one</li>
#     <li>two</li>
# </ol>
